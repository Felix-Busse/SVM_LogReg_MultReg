# %% [markdown]
# # Regressions

# %%
import tensorflow.keras as ks
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import linregress
from scipy.stats import pointbiserialr
from scipy.stats import ttest_ind
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load data and data inspection

# %%
# Useful function:
def rmse(a, b):
    '''Function returns rmse for two array-like objects (must have same length)'''
    return np.sqrt(np.sum(np.square(a - b))/len(a))

# Load raw data
data_raw = pd.read_csv('Salary_dataset.csv')

def tweak_salary_data(df_):
    '''Tweak function to transform raw data into cleaned up-form for analyses.
    Accepts: DataFrame
    Returns: DataFrame'''
    return (df_.rename({'YearsExperience': 'years_exp'}, axis='columns') #use only lowercase and underscore
               .assign(salary=lambda s: s.Salary.astype('int64')) #change name to lowercase ad dtype to int
               .drop(['Unnamed: 0', 'Salary'], axis='columns')) # drop old Salary column and column w/o info

# Apply Tweak_function to raw data
data_salary = tweak_salary_data(data_raw)
# Search for missing data, Result: no muissing data
print(data_salary.isna().any())
# Out:
# years_exp    False
# salary       False
# dtype: bool

# %% [markdown]
# ## Fit Linear regression model to training data

# %%
# Split into train and test data 
X_train, X_test, y_train, y_test = train_test_split(data_salary.years_exp, data_salary.salary) # 75% train
# Create an instance of LinearRegression class
salary_lin_reg = LinearRegression()
# Fit model to training data set
salary_lin_reg.fit(X_train.to_numpy()[:, np.newaxis], y_train) # X has to be 2D
# Make prediction on test data and print coefficient of determination
print(f'Level of determination on training data set \
is R^2 = \t{salary_lin_reg.score(X_test.to_numpy()[:, np.newaxis], y_test):.2f}')
# Out:
# Level of determination on training data set is R^2 = 	0.93

# %% [markdown]
# Measuring model performance with a test sample subset seems unecessary as for linear regression uncertainty of coefficients can be obtained. As linear regression is not an optimization result, these uncertainties can been seen as a measure of how well the model fits the data.
# Sadly scikit learn doesn't provide these uncertainties, but scipy does.

# %%
scipy_lin_reg = linregress(data_salary.years_exp, data_salary.salary)
print(f'Linear regression slope:\t{scipy_lin_reg.slope:.0f}\t+/- {scipy_lin_reg.stderr:.0f}\n\
Linear regression intercept:\t{scipy_lin_reg.intercept:.0f}\t+/- {scipy_lin_reg.intercept_stderr:.0f}')
# Out:
# Linear regression slope:	9450	+/- 379
# Linear regression intercept:	24848	+/- 2307

# %% [markdown]
# Both standard deviation errors of coefficients are <= 10% of coefficient value. Model should be fine.

# %%
# Plotting data and regression

# Calculate two points at min/max of x-data to plot regression line
def calc_prediction(X, m):
    '''Function calculates y, if X (scalar) is given using model m.
    m has to be scipy.stats.linregress'''
    return m.slope*X + scipy_lin_reg.intercept

# Create data frame holding min/max of X and predicted y
scipy_prediction = pd.DataFrame([[data_salary.years_exp.min(), 
                                  calc_prediction(data_salary.years_exp.min(), scipy_lin_reg)], 
                                 [data_salary.years_exp.max(), 
                                  calc_prediction(data_salary.years_exp.max(), scipy_lin_reg)]], 
                                columns=['X', 'y'])

# Plot data as scatter plot, regression as linear curve
fix, ax = plt.subplots()
ax.scatter(data_salary.years_exp, data_salary.salary, label='data points')
ax.plot(scipy_prediction.X, scipy_prediction.y, color='r', label='linear regression')
ax.legend()
ax.set_ylabel('salary [$]')
ax.set_xlabel('years of experience')
ax.set_ylim(0, calc_prediction(data_salary.years_exp.max(), scipy_lin_reg))
ax.set_xlim(0, data_salary.years_exp.max())
ax.set_title('Salary vs. Years of experience')
# Out:
# Text(0.5, 1.0, 'Salary vs. Years of experience')

# %% [markdown]
# ## Multilinear regression on Boston Housing dataset

# %% [markdown]
# ## Load data and data inscpection

# %%
# Data set is seperated by white space and contains no header.
col_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
                'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
boston = pd.read_csv('housing.csv', sep=r'\s+', header=None, names=col_names)

# %%
# Any missing values? result: no
print(f'Any missing data?\t {boston.isna().any().any()}')
# Looking at absolutes of correlation of sales prices with features
print('\nAbsolute of correlation with \'MEDV\'\n', boston.loc[:, 'CRIM':'LSTAT'].corrwith(boston.MEDV).abs())
# Out:
# Any missing data?	 False
#
# Absolute of correlation with 'MEDV'
#  CRIM       0.388305
# ZN         0.360445
# INDUS      0.483725
# CHAS       0.175260
# NOX        0.427321
# RM         0.695360
# AGE        0.376955
# DIS        0.249929
# RAD        0.381626
# TAX        0.468536
# PTRATIO    0.507787
# B          0.333461
# LSTAT      0.737663
# dtype: float64

# %% [markdown]
# All but one values are at least over 0.2, allowing that at least that some correlation exists. Value of "CHAS" is eximend further, because its values are nominal (dichotomous). Point-biserial correlation and p-value is calculated:

# %%
pointbiserialr(boston.CHAS, boston.MEDV)
# Out:
# SignificanceResult(statistic=0.1752601771902984, pvalue=7.390623170519672e-05)

# %% [markdown]
# Low p-value indicate that hypothysis of uncorrelated truth can be rejected. And consequently this variable will also be used in regression. So, in consequence every variable is used.

# %%
# Loop over several train/test-splits to crossvalidate fit
n = 10 #number of loops
boston_regression_results = [] # variable to store results in:
for i in range(n):
    # Create Train/test-split
    X_train, X_test, y_train, y_test = train_test_split(boston.loc[:, 'CRIM':'LSTAT'], boston.MEDV, 
                                                        random_state=np.random.randint(low=0, high=12000))
    # Create model using scikit learn linear regression model
    boston_lin_reg = LinearRegression()
    # Train (fit) model on training data set
    boston_lin_reg.fit(X_train, y_train)
    # Make preduction on test data_set
    boston_prediction = boston_lin_reg.predict(X_test)
    boston_regression_results.append(rmse(boston_prediction, y_test)) # store RMSE in list
    
boston_results = pd.DataFrame(boston_regression_results, columns=['rmse'])
print(f'Multible linear regression results in an error (RMSE) of {boston_results.rmse.mean():.1f} +/- \
{boston_results.rmse.std():.1f}')
# Out:
# Multible linear regression results in an error (RMSE) of 5.1 +/- 0.4

# %% [markdown]
# ## Train neuronal net to compare with

# %%
# transform boston data set to zero mean and unit variance, exclude categorical columns 'CHAS' and target
def transform_boston(df_):
    '''Function takes boston housing data set (as DataFrame) and returns a transformed DataFrame:
    column "CHAS": no transformation (categorical)
    column "MEDV": linear scaling to [0, 1] as it is target'''
    scaler = StandardScaler() # Create instance of standard-scaler
    scaler_minmax = MinMaxScaler() # Create instance of MinMaxScaler to transform target to [0, 1]

    return (pd.DataFrame(scaler.fit_transform(df_),
                         columns=df_.columns.to_list()) # Transform all columns in new DataFrae
            .assign(CHAS=df_.CHAS, # Overwrite "CHAS"-columns as it is categorical and should not be transformed
                    MEDV=scaler_minmax.fit_transform(df_.MEDV.to_numpy()[:, np.newaxis])) # Overwrite
                    # target-column, as it should be transformed with MinMaxScaler
            )

# Apply transformation function
boston_transformed = transform_boston(boston)

# %%
# List to store RMSE on training data in
rmse_training = []
# List to store RMSE on test data in
rmse_test = []

# Fit net to different train/test splits
for i in range(10):
    # Get train and test split of transformed data
    X_train, X_test, y_train, y_test = train_test_split(boston_transformed.loc[:, 'CRIM':'LSTAT'], boston.MEDV,
                                                    random_state=np.random.randint(0, 12000))
    # Define net
    net = ks.Sequential()
    net.add(ks.layers.GaussianNoise(0.25, input_shape=(13,))) #Adding Gaussian noise to input for regularzation
    net.add(ks.layers.Dense(20, activation='tanh')) #First hidden layer
    net.add(ks.layers.Dense(1, activation='linear')) # Output layer
    net.compile(optimizer='adam', metrics='RootMeanSquaredError', loss='mean_squared_error') # compile command
    # Fit net to training data set
    history = net.fit(X_train, y_train, batch_size=16, epochs=300)
    # Store last RMSE on training data set
    rmse_training.append(history.history['root_mean_squared_error'][-1])
    # Store RMSE on test data set
    rmse_test.append(net.evaluate(X_test, y_test)[-1]) # Last returned element is RMSE
# Out:
# Epoch 1/300
# 24/24 [==============================] - 1s 2ms/step - loss: 567.1463 - root_mean_squared_error: 23.8148
# Epoch 2/300
# 24/24 [==============================] - 0s 2ms/step - loss: 554.7729 - root_mean_squared_error: 23.5536
# Epoch 3/300
# 24/24 [==============================] - 0s 2ms/step - loss: 543.0498 - root_mean_squared_error: 23.3034
# Epoch 4/300
# 24/24 [==============================] - 0s 2ms/step - loss: 532.3682 - root_mean_squared_error: 23.0731
# Epoch 5/300
# 24/24 [==============================] - 0s 2ms/step - loss: 523.5323 - root_mean_squared_error: 22.8808
# Epoch 6/300
# 24/24 [==============================] - 0s 2ms/step - loss: 510.7747 - root_mean_squared_error: 22.6003
# Epoch 7/300
# 24/24 [==============================] - 0s 2ms/step - loss: 501.8473 - root_mean_squared_error: 22.4019
# Epoch 8/300
# 24/24 [==============================] - 0s 2ms/step - loss: 488.1759 - root_mean_squared_error: 22.0947
# Epoch 9/300
# 24/24 [==============================] - 0s 2ms/step - loss: 475.2627 - root_mean_squared_error: 21.8005
# Epoch 10/300
# 24/24 [==============================] - 0s 2ms/step - loss: 462.2942 - root_mean_squared_error: 21.5010
# Epoch 11/300
# 24/24 [==============================] - 0s 3ms/step - loss: 448.3893 - root_mean_squared_error: 21.1752
# Epoch 12/300
# 24/24 [==============================] - 0s 2ms/step - loss: 430.9258 - root_mean_squared_error: 20.7588
# Epoch 13/300
# 24/24 [==============================] - 0s 2ms/step - loss: 418.6744 - root_mean_squared_error: 20.4615
# Epoch 14/300
# 24/24 [==============================] - 0s 2ms/step - loss: 405.6018 - root_mean_squared_error: 20.1396
# Epoch 15/300
# 24/24 [==============================] - 0s 2ms/step - loss: 389.2443 - root_mean_squared_error: 19.7293
# Epoch 16/300
# 24/24 [==============================] - 0s 2ms/step - loss: 375.2630 - root_mean_squared_error: 19.3717
# Epoch 17/300
# 24/24 [==============================] - 0s 2ms/step - loss: 359.4724 - root_mean_squared_error: 18.9598
# Epoch 18/300
# 24/24 [==============================] - 0s 2ms/step - loss: 344.1156 - root_mean_squared_error: 18.5504
# Epoch 19/300
# 24/24 [==============================] - 0s 2ms/step - loss: 328.6802 - root_mean_squared_error: 18.1295
# Epoch 20/300
# 24/24 [==============================] - 0s 2ms/step - loss: 308.2946 - root_mean_squared_error: 17.5583
# Epoch 21/300
# 24/24 [==============================] - 0s 2ms/step - loss: 294.2339 - root_mean_squared_error: 17.1532
# Epoch 22/300
# 24/24 [==============================] - 0s 2ms/step - loss: 281.6512 - root_mean_squared_error: 16.7825
# Epoch 23/300
# 24/24 [==============================] - 0s 2ms/step - loss: 263.8624 - root_mean_squared_error: 16.2438
# Epoch 24/300
# 24/24 [==============================] - 0s 2ms/step - loss: 249.1862 - root_mean_squared_error: 15.7856
# Epoch 25/300
# 24/24 [==============================] - 0s 2ms/step - loss: 237.0282 - root_mean_squared_error: 15.3957
# Epoch 26/300
# 24/24 [==============================] - 0s 2ms/step - loss: 220.7983 - root_mean_squared_error: 14.8593
# Epoch 27/300
# 24/24 [==============================] - 0s 2ms/step - loss: 206.9679 - root_mean_squared_error: 14.3864
# Epoch 28/300
# 24/24 [==============================] - 0s 2ms/step - loss: 192.1771 - root_mean_squared_error: 13.8628
# Epoch 29/300
# 24/24 [==============================] - 0s 2ms/step - loss: 179.7196 - root_mean_squared_error: 13.4060
# Epoch 30/300
# 24/24 [==============================] - 0s 2ms/step - loss: 170.1567 - root_mean_squared_error: 13.0444
# Epoch 31/300
# 24/24 [==============================] - 0s 2ms/step - loss: 156.5500 - root_mean_squared_error: 12.5120
# Epoch 32/300
# 24/24 [==============================] - 0s 2ms/step - loss: 145.9729 - root_mean_squared_error: 12.0819
# Epoch 33/300
# 24/24 [==============================] - 0s 2ms/step - loss: 134.5219 - root_mean_squared_error: 11.5984
# Epoch 34/300
# 24/24 [==============================] - 0s 2ms/step - loss: 124.1766 - root_mean_squared_error: 11.1435
# Epoch 35/300
# 24/24 [==============================] - 0s 2ms/step - loss: 118.1163 - root_mean_squared_error: 10.8681
# Epoch 36/300
# 24/24 [==============================] - 0s 2ms/step - loss: 110.0418 - root_mean_squared_error: 10.4901
# Epoch 37/300
# 24/24 [==============================] - 0s 2ms/step - loss: 102.8653 - root_mean_squared_error: 10.1423
# Epoch 38/300
# 24/24 [==============================] - 0s 2ms/step - loss: 95.5145 - root_mean_squared_error: 9.7732
# Epoch 39/300
# 24/24 [==============================] - 0s 2ms/step - loss: 89.0938 - root_mean_squared_error: 9.4390
# Epoch 40/300
# 24/24 [==============================] - 0s 2ms/step - loss: 83.4835 - root_mean_squared_error: 9.1369
# Epoch 41/300
# 24/24 [==============================] - 0s 2ms/step - loss: 78.0955 - root_mean_squared_error: 8.8372
# Epoch 42/300
# 24/24 [==============================] - 0s 2ms/step - loss: 73.6107 - root_mean_squared_error: 8.5797
# Epoch 43/300
# 24/24 [==============================] - 0s 2ms/step - loss: 71.4536 - root_mean_squared_error: 8.4530
# Epoch 44/300
# 24/24 [==============================] - 0s 2ms/step - loss: 66.7771 - root_mean_squared_error: 8.1717
# Epoch 45/300
# 24/24 [==============================] - 0s 2ms/step - loss: 64.5398 - root_mean_squared_error: 8.0337
# Epoch 46/300
# 24/24 [==============================] - 0s 2ms/step - loss: 61.8467 - root_mean_squared_error: 7.8643
# Epoch 47/300
# 24/24 [==============================] - 0s 2ms/step - loss: 58.6326 - root_mean_squared_error: 7.6572
# Epoch 48/300
# 24/24 [==============================] - 0s 2ms/step - loss: 56.5438 - root_mean_squared_error: 7.5196
# Epoch 49/300
# 24/24 [==============================] - 0s 2ms/step - loss: 53.5759 - root_mean_squared_error: 7.3196
# Epoch 50/300
# 24/24 [==============================] - 0s 2ms/step - loss: 52.0329 - root_mean_squared_error: 7.2134
# Epoch 51/300
# 24/24 [==============================] - 0s 2ms/step - loss: 51.0373 - root_mean_squared_error: 7.1440
# Epoch 52/300
# 24/24 [==============================] - 0s 2ms/step - loss: 48.5343 - root_mean_squared_error: 6.9667
# Epoch 53/300
# 24/24 [==============================] - 0s 2ms/step - loss: 47.6651 - root_mean_squared_error: 6.9040
# Epoch 54/300
# 24/24 [==============================] - 0s 2ms/step - loss: 47.7041 - root_mean_squared_error: 6.9068
# Epoch 55/300
# 24/24 [==============================] - 0s 2ms/step - loss: 46.5854 - root_mean_squared_error: 6.8253
# Epoch 56/300
# 24/24 [==============================] - 0s 2ms/step - loss: 44.5778 - root_mean_squared_error: 6.6767
# Epoch 57/300
# 24/24 [==============================] - 0s 2ms/step - loss: 44.1594 - root_mean_squared_error: 6.6453
# Epoch 58/300
# 24/24 [==============================] - 0s 2ms/step - loss: 43.5940 - root_mean_squared_error: 6.6026
# Epoch 59/300
# 24/24 [==============================] - 0s 2ms/step - loss: 42.1449 - root_mean_squared_error: 6.4919
# Epoch 60/300
# 24/24 [==============================] - 0s 2ms/step - loss: 41.7764 - root_mean_squared_error: 6.4635
# Epoch 61/300
# 24/24 [==============================] - 0s 2ms/step - loss: 41.5259 - root_mean_squared_error: 6.4441
# Epoch 62/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.8275 - root_mean_squared_error: 6.3896
# Epoch 63/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.4190 - root_mean_squared_error: 6.3576
# Epoch 64/300
# 24/24 [==============================] - 0s 2ms/step - loss: 39.6959 - root_mean_squared_error: 6.3005
# Epoch 65/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.1519 - root_mean_squared_error: 6.3366
# Epoch 66/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.6790 - root_mean_squared_error: 6.2192
# Epoch 67/300
# 24/24 [==============================] - 0s 2ms/step - loss: 39.5785 - root_mean_squared_error: 6.2911
# Epoch 68/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.5991 - root_mean_squared_error: 6.2128
# Epoch 69/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.5617 - root_mean_squared_error: 6.2098
# Epoch 70/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.3959 - root_mean_squared_error: 6.1152
# Epoch 71/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.6991 - root_mean_squared_error: 6.2209
# Epoch 72/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.0972 - root_mean_squared_error: 6.1723
# Epoch 73/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.6944 - root_mean_squared_error: 6.1396
# Epoch 74/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.0497 - root_mean_squared_error: 6.0868
# Epoch 75/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.1572 - root_mean_squared_error: 6.0957
# Epoch 76/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.5826 - root_mean_squared_error: 6.0484
# Epoch 77/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.7312 - root_mean_squared_error: 5.9776
# Epoch 78/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.0073 - root_mean_squared_error: 6.0006
# Epoch 79/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.5409 - root_mean_squared_error: 5.9616
# Epoch 80/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.7027 - root_mean_squared_error: 5.9752
# Epoch 81/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.1768 - root_mean_squared_error: 5.9310
# Epoch 82/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.3473 - root_mean_squared_error: 5.8607
# Epoch 83/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.9960 - root_mean_squared_error: 5.8306
# Epoch 84/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.9296 - root_mean_squared_error: 5.8249
# Epoch 85/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.8671 - root_mean_squared_error: 5.9048
# Epoch 86/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.8558 - root_mean_squared_error: 5.7320
# Epoch 87/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.2543 - root_mean_squared_error: 5.9375
# Epoch 88/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.8940 - root_mean_squared_error: 5.8219
# Epoch 89/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.0165 - root_mean_squared_error: 5.7460
# Epoch 90/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.4157 - root_mean_squared_error: 5.7806
# Epoch 91/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.4804 - root_mean_squared_error: 5.6992
# Epoch 92/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.6683 - root_mean_squared_error: 5.6275
# Epoch 93/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.9127 - root_mean_squared_error: 5.7370
# Epoch 94/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.0729 - root_mean_squared_error: 5.7509
# Epoch 95/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.5518 - root_mean_squared_error: 5.6171
# Epoch 96/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.8212 - root_mean_squared_error: 5.7290
# Epoch 97/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.8574 - root_mean_squared_error: 5.6442
# Epoch 98/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.1557 - root_mean_squared_error: 5.5817
# Epoch 99/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.2109 - root_mean_squared_error: 5.6755
# Epoch 100/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.2602 - root_mean_squared_error: 5.6798
# Epoch 101/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.0281 - root_mean_squared_error: 5.5703
# Epoch 102/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.5975 - root_mean_squared_error: 5.5315
# Epoch 103/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.5271 - root_mean_squared_error: 5.5251
# Epoch 104/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.1280 - root_mean_squared_error: 5.4889
# Epoch 105/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.3558 - root_mean_squared_error: 5.5096
# Epoch 106/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.6642 - root_mean_squared_error: 5.5375
# Epoch 107/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.0843 - root_mean_squared_error: 5.4849
# Epoch 108/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.8370 - root_mean_squared_error: 5.5531
# Epoch 109/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.2939 - root_mean_squared_error: 5.5040
# Epoch 110/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.2026 - root_mean_squared_error: 5.4957
# Epoch 111/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.1701 - root_mean_squared_error: 5.4927
# Epoch 112/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.5850 - root_mean_squared_error: 5.4392
# Epoch 113/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.8377 - root_mean_squared_error: 5.4624
# Epoch 114/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.8449 - root_mean_squared_error: 5.3707
# Epoch 115/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.2792 - root_mean_squared_error: 5.4110
# Epoch 116/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.5048 - root_mean_squared_error: 5.4318
# Epoch 117/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.7740 - root_mean_squared_error: 5.3641
# Epoch 118/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.5907 - root_mean_squared_error: 5.3470
# Epoch 119/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.6743 - root_mean_squared_error: 5.2606
# Epoch 120/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.4059 - root_mean_squared_error: 5.3297
# Epoch 121/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.2749 - root_mean_squared_error: 5.2225
# Epoch 122/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.9829 - root_mean_squared_error: 5.2899
# Epoch 123/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.4484 - root_mean_squared_error: 5.2391
# Epoch 124/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.7028 - root_mean_squared_error: 5.2633
# Epoch 125/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.7366 - root_mean_squared_error: 5.3607
# Epoch 126/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.9558 - root_mean_squared_error: 5.1919
# Epoch 127/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.5156 - root_mean_squared_error: 5.2455
# Epoch 128/300
# 24/24 [==============================] - 0s 1ms/step - loss: 26.3319 - root_mean_squared_error: 5.1315
# Epoch 129/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.1175 - root_mean_squared_error: 5.3026
# Epoch 130/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.3440 - root_mean_squared_error: 5.2292
# Epoch 131/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.1225 - root_mean_squared_error: 5.2079
# Epoch 132/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.6179 - root_mean_squared_error: 5.1593
# Epoch 133/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.1900 - root_mean_squared_error: 5.1176
# Epoch 134/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.9941 - root_mean_squared_error: 5.0984
# Epoch 135/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.8638 - root_mean_squared_error: 5.0856
# Epoch 136/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.1641 - root_mean_squared_error: 5.2119
# Epoch 137/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.8034 - root_mean_squared_error: 5.0797
# Epoch 138/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.7480 - root_mean_squared_error: 5.1719
# Epoch 139/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.8735 - root_mean_squared_error: 5.0866
# Epoch 140/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.5561 - root_mean_squared_error: 5.1533
# Epoch 141/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.2574 - root_mean_squared_error: 5.0257
# Epoch 142/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.8728 - root_mean_squared_error: 5.0865
# Epoch 143/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.6859 - root_mean_squared_error: 4.9685
# Epoch 144/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.0716 - root_mean_squared_error: 5.1060
# Epoch 145/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.3339 - root_mean_squared_error: 5.0333
# Epoch 146/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.3512 - root_mean_squared_error: 5.1333
# Epoch 147/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.5842 - root_mean_squared_error: 4.9582
# Epoch 148/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.6375 - root_mean_squared_error: 5.0634
# Epoch 149/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.6164 - root_mean_squared_error: 4.9615
# Epoch 150/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.0611 - root_mean_squared_error: 5.0061
# Epoch 151/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.1051 - root_mean_squared_error: 4.9097
# Epoch 152/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.9542 - root_mean_squared_error: 4.9954
# Epoch 153/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.1605 - root_mean_squared_error: 5.1147
# Epoch 154/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.4335 - root_mean_squared_error: 4.9430
# Epoch 155/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.9760 - root_mean_squared_error: 4.8965
# Epoch 156/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.8821 - root_mean_squared_error: 4.9882
# Epoch 157/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.8228 - root_mean_squared_error: 4.8809
# Epoch 158/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.3031 - root_mean_squared_error: 4.9298
# Epoch 159/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.2906 - root_mean_squared_error: 5.0290
# Epoch 160/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.0464 - root_mean_squared_error: 4.9037
# Epoch 161/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.5659 - root_mean_squared_error: 4.8545
# Epoch 162/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.9443 - root_mean_squared_error: 4.7900
# Epoch 163/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.8595 - root_mean_squared_error: 4.9859
# Epoch 164/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.6836 - root_mean_squared_error: 4.9683
# Epoch 165/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.1902 - root_mean_squared_error: 4.8156
# Epoch 166/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.9651 - root_mean_squared_error: 4.9965
# Epoch 167/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.0975 - root_mean_squared_error: 4.9089
# Epoch 168/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.2394 - root_mean_squared_error: 4.8207
# Epoch 169/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.4508 - root_mean_squared_error: 4.8426
# Epoch 170/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.0504 - root_mean_squared_error: 4.6958
# Epoch 171/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.6565 - root_mean_squared_error: 4.8638
# Epoch 172/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.4058 - root_mean_squared_error: 4.8380
# Epoch 173/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.6552 - root_mean_squared_error: 4.7597
# Epoch 174/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.9245 - root_mean_squared_error: 4.6824
# Epoch 175/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.3079 - root_mean_squared_error: 4.8278
# Epoch 176/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.1207 - root_mean_squared_error: 4.8084
# Epoch 177/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.1736 - root_mean_squared_error: 4.7089
# Epoch 178/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.2847 - root_mean_squared_error: 4.7207
# Epoch 179/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.2437 - root_mean_squared_error: 4.7163
# Epoch 180/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.7553 - root_mean_squared_error: 4.7703
# Epoch 181/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.5727 - root_mean_squared_error: 4.7511
# Epoch 182/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.2984 - root_mean_squared_error: 4.7221
# Epoch 183/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.0549 - root_mean_squared_error: 4.5886
# Epoch 184/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.9712 - root_mean_squared_error: 4.6873
# Epoch 185/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.5481 - root_mean_squared_error: 4.6420
# Epoch 186/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.2731 - root_mean_squared_error: 4.7194
# Epoch 187/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.1549 - root_mean_squared_error: 4.7069
# Epoch 188/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.3062 - root_mean_squared_error: 4.7229
# Epoch 189/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.0004 - root_mean_squared_error: 4.6905
# Epoch 190/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.6274 - root_mean_squared_error: 4.5417
# Epoch 191/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.4424 - root_mean_squared_error: 4.7373
# Epoch 192/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.4387 - root_mean_squared_error: 4.6302
# Epoch 193/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.5054 - root_mean_squared_error: 4.5283
# Epoch 194/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.1148 - root_mean_squared_error: 4.7026
# Epoch 195/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.6433 - root_mean_squared_error: 4.6522
# Epoch 196/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.7482 - root_mean_squared_error: 4.6635
# Epoch 197/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.7777 - root_mean_squared_error: 4.5583
# Epoch 198/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.4397 - root_mean_squared_error: 4.4090
# Epoch 199/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.4431 - root_mean_squared_error: 4.6307
# Epoch 200/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.2462 - root_mean_squared_error: 4.4996
# Epoch 201/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.7521 - root_mean_squared_error: 4.5554
# Epoch 202/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.9038 - root_mean_squared_error: 4.5721
# Epoch 203/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.0210 - root_mean_squared_error: 4.5849
# Epoch 204/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.2045 - root_mean_squared_error: 4.4949
# Epoch 205/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.1114 - root_mean_squared_error: 4.7023
# Epoch 206/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.6352 - root_mean_squared_error: 4.4312
# Epoch 207/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.4167 - root_mean_squared_error: 4.4064
# Epoch 208/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.9777 - root_mean_squared_error: 4.5801
# Epoch 209/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.0520 - root_mean_squared_error: 4.5882
# Epoch 210/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.3919 - root_mean_squared_error: 4.6251
# Epoch 211/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.4546 - root_mean_squared_error: 4.6319
# Epoch 212/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.0935 - root_mean_squared_error: 4.5928
# Epoch 213/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.9134 - root_mean_squared_error: 4.3490
# Epoch 214/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.4195 - root_mean_squared_error: 4.4068
# Epoch 215/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.7778 - root_mean_squared_error: 4.4472
# Epoch 216/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.0766 - root_mean_squared_error: 4.4807
# Epoch 217/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.8358 - root_mean_squared_error: 4.4537
# Epoch 218/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.0037 - root_mean_squared_error: 4.3593
# Epoch 219/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.7784 - root_mean_squared_error: 4.3334
# Epoch 220/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.0772 - root_mean_squared_error: 4.4808
# Epoch 221/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.6307 - root_mean_squared_error: 4.4307
# Epoch 222/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.7140 - root_mean_squared_error: 4.4400
# Epoch 223/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.9668 - root_mean_squared_error: 4.3551
# Epoch 224/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.0649 - root_mean_squared_error: 4.3663
# Epoch 225/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.4618 - root_mean_squared_error: 4.4116
# Epoch 226/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.4757 - root_mean_squared_error: 4.2983
# Epoch 227/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.2649 - root_mean_squared_error: 4.3892
# Epoch 228/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.1873 - root_mean_squared_error: 4.3803
# Epoch 229/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.6147 - root_mean_squared_error: 4.5403
# Epoch 230/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.0055 - root_mean_squared_error: 4.3595
# Epoch 231/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.8973 - root_mean_squared_error: 4.4606
# Epoch 232/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.5808 - root_mean_squared_error: 4.4250
# Epoch 233/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.2774 - root_mean_squared_error: 4.3906
# Epoch 234/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.5372 - root_mean_squared_error: 4.3055
# Epoch 235/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.5269 - root_mean_squared_error: 4.4189
# Epoch 236/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.2824 - root_mean_squared_error: 4.2758
# Epoch 237/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9059 - root_mean_squared_error: 4.2315
# Epoch 238/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.1621 - root_mean_squared_error: 4.2617
# Epoch 239/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.6466 - root_mean_squared_error: 4.3182
# Epoch 240/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.2434 - root_mean_squared_error: 4.1525
# Epoch 241/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.7665 - root_mean_squared_error: 4.2150
# Epoch 242/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.0612 - root_mean_squared_error: 4.4790
# Epoch 243/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.4552 - root_mean_squared_error: 4.1779
# Epoch 244/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.1835 - root_mean_squared_error: 4.6026
# Epoch 245/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.8860 - root_mean_squared_error: 4.2292
# Epoch 246/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.2872 - root_mean_squared_error: 4.1578
# Epoch 247/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.1207 - root_mean_squared_error: 4.2568
# Epoch 248/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.8529 - root_mean_squared_error: 4.2253
# Epoch 249/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.9900 - root_mean_squared_error: 4.3577
# Epoch 250/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.1948 - root_mean_squared_error: 4.2655
# Epoch 251/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.6485 - root_mean_squared_error: 4.0803
# Epoch 252/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.4637 - root_mean_squared_error: 4.2969
# Epoch 253/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.1358 - root_mean_squared_error: 4.3744
# Epoch 254/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.4558 - root_mean_squared_error: 4.1780
# Epoch 255/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.0322 - root_mean_squared_error: 4.2464
# Epoch 256/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.4619 - root_mean_squared_error: 4.1787
# Epoch 257/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.3653 - root_mean_squared_error: 4.2855
# Epoch 258/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.6593 - root_mean_squared_error: 4.0816
# Epoch 259/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.2432 - root_mean_squared_error: 4.2712
# Epoch 260/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.1877 - root_mean_squared_error: 4.2647
# Epoch 261/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.3847 - root_mean_squared_error: 4.0478
# Epoch 262/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5411 - root_mean_squared_error: 4.0671
# Epoch 263/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9346 - root_mean_squared_error: 4.2349
# Epoch 264/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.1936 - root_mean_squared_error: 4.0241
# Epoch 265/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.9812 - root_mean_squared_error: 4.1208
# Epoch 266/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5187 - root_mean_squared_error: 4.0643
# Epoch 267/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.1354 - root_mean_squared_error: 4.3744
# Epoch 268/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.1127 - root_mean_squared_error: 4.1367
# Epoch 269/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.5685 - root_mean_squared_error: 4.1915
# Epoch 270/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.8203 - root_mean_squared_error: 4.1013
# Epoch 271/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.3013 - root_mean_squared_error: 4.1595
# Epoch 272/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.0617 - root_mean_squared_error: 4.3660
# Epoch 273/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.2856 - root_mean_squared_error: 4.1576
# Epoch 274/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5850 - root_mean_squared_error: 4.0725
# Epoch 275/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.1428 - root_mean_squared_error: 4.2594
# Epoch 276/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.4611 - root_mean_squared_error: 4.1787
# Epoch 277/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.6187 - root_mean_squared_error: 4.1975
# Epoch 278/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5708 - root_mean_squared_error: 4.0707
# Epoch 279/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.3279 - root_mean_squared_error: 4.1627
# Epoch 280/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.9449 - root_mean_squared_error: 4.1164
# Epoch 281/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.3334 - root_mean_squared_error: 4.2818
# Epoch 282/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.7543 - root_mean_squared_error: 4.2136
# Epoch 283/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.2211 - root_mean_squared_error: 4.0275
# Epoch 284/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.9216 - root_mean_squared_error: 3.9902
# Epoch 285/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.5878 - root_mean_squared_error: 4.1938
# Epoch 286/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.0995 - root_mean_squared_error: 4.1352
# Epoch 287/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.3267 - root_mean_squared_error: 4.1625
# Epoch 288/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.3538 - root_mean_squared_error: 4.0440
# Epoch 289/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.2179 - root_mean_squared_error: 4.1494
# Epoch 290/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.9460 - root_mean_squared_error: 3.9932
# Epoch 291/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9011 - root_mean_squared_error: 4.2310
# Epoch 292/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5196 - root_mean_squared_error: 4.0644
# Epoch 293/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.9590 - root_mean_squared_error: 4.1181
# Epoch 294/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.3275 - root_mean_squared_error: 4.0407
# Epoch 295/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5311 - root_mean_squared_error: 4.0658
# Epoch 296/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.1350 - root_mean_squared_error: 3.8904
# Epoch 297/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.2999 - root_mean_squared_error: 4.1593
# Epoch 298/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.7930 - root_mean_squared_error: 4.0979
# Epoch 299/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.3481 - root_mean_squared_error: 4.0433
# Epoch 300/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.3899 - root_mean_squared_error: 4.0484
# 4/4 [==============================] - 0s 3ms/step - loss: 16.4465 - root_mean_squared_error: 4.0554
# Epoch 1/300
# 24/24 [==============================] - 1s 2ms/step - loss: 599.6469 - root_mean_squared_error: 24.4877
# Epoch 2/300
# 24/24 [==============================] - 0s 2ms/step - loss: 585.9349 - root_mean_squared_error: 24.2061
# Epoch 3/300
# 24/24 [==============================] - 0s 2ms/step - loss: 575.2281 - root_mean_squared_error: 23.9839
# Epoch 4/300
# 24/24 [==============================] - 0s 2ms/step - loss: 566.3219 - root_mean_squared_error: 23.7975
# Epoch 5/300
# 24/24 [==============================] - 0s 2ms/step - loss: 555.4885 - root_mean_squared_error: 23.5688
# Epoch 6/300
# 24/24 [==============================] - 0s 2ms/step - loss: 545.4635 - root_mean_squared_error: 23.3552
# Epoch 7/300
# 24/24 [==============================] - 0s 2ms/step - loss: 533.6057 - root_mean_squared_error: 23.0999
# Epoch 8/300
# 24/24 [==============================] - 0s 2ms/step - loss: 519.9956 - root_mean_squared_error: 22.8034
# Epoch 9/300
# 24/24 [==============================] - 0s 2ms/step - loss: 508.3153 - root_mean_squared_error: 22.5458
# Epoch 10/300
# 24/24 [==============================] - 0s 2ms/step - loss: 495.2641 - root_mean_squared_error: 22.2545
# Epoch 11/300
# 24/24 [==============================] - 0s 2ms/step - loss: 480.4986 - root_mean_squared_error: 21.9203
# Epoch 12/300
# 24/24 [==============================] - 0s 2ms/step - loss: 464.2618 - root_mean_squared_error: 21.5467
# Epoch 13/300
# 24/24 [==============================] - 0s 2ms/step - loss: 449.0721 - root_mean_squared_error: 21.1913
# Epoch 14/300
# 24/24 [==============================] - 0s 2ms/step - loss: 431.7349 - root_mean_squared_error: 20.7782
# Epoch 15/300
# 24/24 [==============================] - 0s 2ms/step - loss: 411.3239 - root_mean_squared_error: 20.2811
# Epoch 16/300
# 24/24 [==============================] - 0s 2ms/step - loss: 396.2214 - root_mean_squared_error: 19.9053
# Epoch 17/300
# 24/24 [==============================] - 0s 2ms/step - loss: 377.3509 - root_mean_squared_error: 19.4255
# Epoch 18/300
# 24/24 [==============================] - 0s 2ms/step - loss: 362.9932 - root_mean_squared_error: 19.0524
# Epoch 19/300
# 24/24 [==============================] - 0s 2ms/step - loss: 342.1425 - root_mean_squared_error: 18.4971
# Epoch 20/300
# 24/24 [==============================] - 0s 2ms/step - loss: 324.8828 - root_mean_squared_error: 18.0245
# Epoch 21/300
# 24/24 [==============================] - 0s 2ms/step - loss: 305.1132 - root_mean_squared_error: 17.4675
# Epoch 22/300
# 24/24 [==============================] - 0s 2ms/step - loss: 291.8194 - root_mean_squared_error: 17.0827
# Epoch 23/300
# 24/24 [==============================] - 0s 2ms/step - loss: 274.3233 - root_mean_squared_error: 16.5627
# Epoch 24/300
# 24/24 [==============================] - 0s 2ms/step - loss: 259.7786 - root_mean_squared_error: 16.1176
# Epoch 25/300
# 24/24 [==============================] - 0s 2ms/step - loss: 244.8995 - root_mean_squared_error: 15.6493
# Epoch 26/300
# 24/24 [==============================] - 0s 2ms/step - loss: 231.0217 - root_mean_squared_error: 15.1994
# Epoch 27/300
# 24/24 [==============================] - 0s 2ms/step - loss: 215.1756 - root_mean_squared_error: 14.6689
# Epoch 28/300
# 24/24 [==============================] - 0s 2ms/step - loss: 201.2626 - root_mean_squared_error: 14.1867
# Epoch 29/300
# 24/24 [==============================] - 0s 2ms/step - loss: 191.3789 - root_mean_squared_error: 13.8340
# Epoch 30/300
# 24/24 [==============================] - 0s 2ms/step - loss: 175.9622 - root_mean_squared_error: 13.2651
# Epoch 31/300
# 24/24 [==============================] - 0s 2ms/step - loss: 167.1804 - root_mean_squared_error: 12.9298
# Epoch 32/300
# 24/24 [==============================] - 0s 2ms/step - loss: 156.0522 - root_mean_squared_error: 12.4921
# Epoch 33/300
# 24/24 [==============================] - 0s 2ms/step - loss: 145.3823 - root_mean_squared_error: 12.0575
# Epoch 34/300
# 24/24 [==============================] - 0s 2ms/step - loss: 134.3016 - root_mean_squared_error: 11.5889
# Epoch 35/300
# 24/24 [==============================] - 0s 2ms/step - loss: 126.5795 - root_mean_squared_error: 11.2508
# Epoch 36/300
# 24/24 [==============================] - 0s 2ms/step - loss: 117.6378 - root_mean_squared_error: 10.8461
# Epoch 37/300
# 24/24 [==============================] - 0s 2ms/step - loss: 110.8969 - root_mean_squared_error: 10.5308
# Epoch 38/300
# 24/24 [==============================] - 0s 2ms/step - loss: 106.8091 - root_mean_squared_error: 10.3348
# Epoch 39/300
# 24/24 [==============================] - 0s 2ms/step - loss: 99.1049 - root_mean_squared_error: 9.9551
# Epoch 40/300
# 24/24 [==============================] - 0s 2ms/step - loss: 93.2927 - root_mean_squared_error: 9.6588
# Epoch 41/300
# 24/24 [==============================] - 0s 2ms/step - loss: 88.5486 - root_mean_squared_error: 9.4100
# Epoch 42/300
# 24/24 [==============================] - 0s 2ms/step - loss: 82.2879 - root_mean_squared_error: 9.0713
# Epoch 43/300
# 24/24 [==============================] - 0s 2ms/step - loss: 80.3034 - root_mean_squared_error: 8.9612
# Epoch 44/300
# 24/24 [==============================] - 0s 2ms/step - loss: 75.8882 - root_mean_squared_error: 8.7114
# Epoch 45/300
# 24/24 [==============================] - 0s 2ms/step - loss: 73.3528 - root_mean_squared_error: 8.5646
# Epoch 46/300
# 24/24 [==============================] - 0s 2ms/step - loss: 68.7953 - root_mean_squared_error: 8.2943
# Epoch 47/300
# 24/24 [==============================] - 0s 2ms/step - loss: 67.3220 - root_mean_squared_error: 8.2050
# Epoch 48/300
# 24/24 [==============================] - 0s 2ms/step - loss: 62.8457 - root_mean_squared_error: 7.9275
# Epoch 49/300
# 24/24 [==============================] - 0s 2ms/step - loss: 60.9497 - root_mean_squared_error: 7.8070
# Epoch 50/300
# 24/24 [==============================] - 0s 2ms/step - loss: 58.1236 - root_mean_squared_error: 7.6239
# Epoch 51/300
# 24/24 [==============================] - 0s 2ms/step - loss: 56.3844 - root_mean_squared_error: 7.5090
# Epoch 52/300
# 24/24 [==============================] - 0s 2ms/step - loss: 56.1177 - root_mean_squared_error: 7.4912
# Epoch 53/300
# 24/24 [==============================] - 0s 2ms/step - loss: 53.3120 - root_mean_squared_error: 7.3015
# Epoch 54/300
# 24/24 [==============================] - 0s 2ms/step - loss: 51.5391 - root_mean_squared_error: 7.1791
# Epoch 55/300
# 24/24 [==============================] - 0s 2ms/step - loss: 51.6569 - root_mean_squared_error: 7.1873
# Epoch 56/300
# 24/24 [==============================] - 0s 2ms/step - loss: 49.9044 - root_mean_squared_error: 7.0643
# Epoch 57/300
# 24/24 [==============================] - 0s 2ms/step - loss: 48.8360 - root_mean_squared_error: 6.9883
# Epoch 58/300
# 24/24 [==============================] - 0s 2ms/step - loss: 48.0553 - root_mean_squared_error: 6.9322
# Epoch 59/300
# 24/24 [==============================] - 0s 2ms/step - loss: 47.8671 - root_mean_squared_error: 6.9186
# Epoch 60/300
# 24/24 [==============================] - 0s 2ms/step - loss: 46.8162 - root_mean_squared_error: 6.8422
# Epoch 61/300
# 24/24 [==============================] - 0s 2ms/step - loss: 45.4215 - root_mean_squared_error: 6.7396
# Epoch 62/300
# 24/24 [==============================] - 0s 2ms/step - loss: 45.2882 - root_mean_squared_error: 6.7297
# Epoch 63/300
# 24/24 [==============================] - 0s 2ms/step - loss: 44.8274 - root_mean_squared_error: 6.6953
# Epoch 64/300
# 24/24 [==============================] - 0s 2ms/step - loss: 44.8612 - root_mean_squared_error: 6.6979
# Epoch 65/300
# 24/24 [==============================] - 0s 2ms/step - loss: 44.1696 - root_mean_squared_error: 6.6460
# Epoch 66/300
# 24/24 [==============================] - 0s 2ms/step - loss: 43.6564 - root_mean_squared_error: 6.6073
# Epoch 67/300
# 24/24 [==============================] - 0s 2ms/step - loss: 43.2464 - root_mean_squared_error: 6.5762
# Epoch 68/300
# 24/24 [==============================] - 0s 2ms/step - loss: 42.6073 - root_mean_squared_error: 6.5274
# Epoch 69/300
# 24/24 [==============================] - 0s 2ms/step - loss: 42.2289 - root_mean_squared_error: 6.4984
# Epoch 70/300
# 24/24 [==============================] - 0s 2ms/step - loss: 42.8346 - root_mean_squared_error: 6.5448
# Epoch 71/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.9625 - root_mean_squared_error: 6.4002
# Epoch 72/300
# 24/24 [==============================] - 0s 2ms/step - loss: 41.4047 - root_mean_squared_error: 6.4346
# Epoch 73/300
# 24/24 [==============================] - 0s 2ms/step - loss: 41.1551 - root_mean_squared_error: 6.4152
# Epoch 74/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.6815 - root_mean_squared_error: 6.3782
# Epoch 75/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.3372 - root_mean_squared_error: 6.3512
# Epoch 76/300
# 24/24 [==============================] - 0s 2ms/step - loss: 39.7470 - root_mean_squared_error: 6.3045
# Epoch 77/300
# 24/24 [==============================] - 0s 2ms/step - loss: 39.9550 - root_mean_squared_error: 6.3210
# Epoch 78/300
# 24/24 [==============================] - 0s 2ms/step - loss: 39.8554 - root_mean_squared_error: 6.3131
# Epoch 79/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.1730 - root_mean_squared_error: 6.3382
# Epoch 80/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.9399 - root_mean_squared_error: 6.2402
# Epoch 81/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.3956 - root_mean_squared_error: 6.3558
# Epoch 82/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.5426 - root_mean_squared_error: 6.1272
# Epoch 83/300
# 24/24 [==============================] - 0s 2ms/step - loss: 39.4047 - root_mean_squared_error: 6.2773
# Epoch 84/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.4646 - root_mean_squared_error: 6.2020
# Epoch 85/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.8199 - root_mean_squared_error: 6.0679
# Epoch 86/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.5320 - root_mean_squared_error: 6.0442
# Epoch 87/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.7915 - root_mean_squared_error: 6.1475
# Epoch 88/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.3658 - root_mean_squared_error: 6.1128
# Epoch 89/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.6624 - root_mean_squared_error: 6.0549
# Epoch 90/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.1549 - root_mean_squared_error: 6.0955
# Epoch 91/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.2491 - root_mean_squared_error: 6.0207
# Epoch 92/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.2342 - root_mean_squared_error: 6.0195
# Epoch 93/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.6173 - root_mean_squared_error: 5.9680
# Epoch 94/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.4320 - root_mean_squared_error: 6.0359
# Epoch 95/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.9535 - root_mean_squared_error: 5.9961
# Epoch 96/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.4331 - root_mean_squared_error: 5.9526
# Epoch 97/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.0286 - root_mean_squared_error: 5.9185
# Epoch 98/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.6786 - root_mean_squared_error: 5.8889
# Epoch 99/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.5285 - root_mean_squared_error: 5.8761
# Epoch 100/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.2012 - root_mean_squared_error: 5.8482
# Epoch 101/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.5688 - root_mean_squared_error: 5.7939
# Epoch 102/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.4741 - root_mean_squared_error: 5.8715
# Epoch 103/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.8489 - root_mean_squared_error: 5.9033
# Epoch 104/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.7562 - root_mean_squared_error: 5.7233
# Epoch 105/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.5534 - root_mean_squared_error: 5.7056
# Epoch 106/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.1693 - root_mean_squared_error: 5.7593
# Epoch 107/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.3503 - root_mean_squared_error: 5.6877
# Epoch 108/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.8854 - root_mean_squared_error: 5.7346
# Epoch 109/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.3647 - root_mean_squared_error: 5.6004
# Epoch 110/300
# ...
# 24/24 [==============================] - 0s 1ms/step - loss: 26.3372 - root_mean_squared_error: 5.1320
# Epoch 166/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.3977 - root_mean_squared_error: 5.0396
# Epoch 167/300
# 24/24 [==============================] - 0s 1ms/step - loss: 26.8094 - root_mean_squared_error: 5.1778
# Epoch 168/300
# 24/24 [==============================] - 0s 1ms/step - loss: 27.8364 - root_mean_squared_error: 5.2760
# Epoch 169/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.7684 - root_mean_squared_error: 5.0763
# Epoch 170/300
# 24/24 [==============================] - 0s 1ms/step - loss: 26.2165 - root_mean_squared_error: 5.1202
# Epoch 171/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.7243 - root_mean_squared_error: 5.0719
# Epoch 172/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.2726 - root_mean_squared_error: 5.0272
# Epoch 173/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.1252 - root_mean_squared_error: 4.9117
# Epoch 174/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.0405 - root_mean_squared_error: 4.9031
# Epoch 175/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.3307 - root_mean_squared_error: 5.0330
# Epoch 176/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.5076 - root_mean_squared_error: 4.9505
# Epoch 177/300
# 24/24 [==============================] - 0s 1ms/step - loss: 26.1014 - root_mean_squared_error: 5.1090
# Epoch 178/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.8560 - root_mean_squared_error: 4.9856
# Epoch 179/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.1510 - root_mean_squared_error: 5.0151
# Epoch 180/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.0480 - root_mean_squared_error: 4.8008
# Epoch 181/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.0711 - root_mean_squared_error: 4.9062
# Epoch 182/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.9301 - root_mean_squared_error: 5.0922
# Epoch 183/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.5588 - root_mean_squared_error: 4.9557
# Epoch 184/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.2133 - root_mean_squared_error: 5.0213
# Epoch 185/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.5037 - root_mean_squared_error: 4.7438
# Epoch 186/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.9764 - root_mean_squared_error: 4.8966
# Epoch 187/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.4732 - root_mean_squared_error: 4.9470
# Epoch 188/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.2248 - root_mean_squared_error: 4.8192
# Epoch 189/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.2545 - root_mean_squared_error: 4.8223
# Epoch 190/300
# 24/24 [==============================] - 0s 1ms/step - loss: 25.1384 - root_mean_squared_error: 5.0138
# Epoch 191/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.1017 - root_mean_squared_error: 4.8064
# Epoch 192/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.1385 - root_mean_squared_error: 4.8102
# Epoch 193/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.3524 - root_mean_squared_error: 4.7278
# Epoch 194/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.8951 - root_mean_squared_error: 4.8883
# Epoch 195/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.1741 - root_mean_squared_error: 4.8139
# Epoch 196/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.1541 - root_mean_squared_error: 4.9147
# Epoch 197/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.6965 - root_mean_squared_error: 4.8679
# Epoch 198/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.2363 - root_mean_squared_error: 4.9230
# Epoch 199/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.6736 - root_mean_squared_error: 4.7617
# Epoch 200/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.4110 - root_mean_squared_error: 4.8385
# Epoch 201/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.6324 - root_mean_squared_error: 4.6511
# Epoch 202/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.3969 - root_mean_squared_error: 4.9393
# Epoch 203/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.1082 - root_mean_squared_error: 4.8071
# Epoch 204/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.0331 - root_mean_squared_error: 4.6939
# Epoch 205/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.5296 - root_mean_squared_error: 4.6400
# Epoch 206/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.9380 - root_mean_squared_error: 4.7894
# Epoch 207/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.4778 - root_mean_squared_error: 4.7411
# Epoch 208/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.2909 - root_mean_squared_error: 4.7213
# Epoch 209/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.8738 - root_mean_squared_error: 4.6769
# Epoch 210/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.7045 - root_mean_squared_error: 4.6588
# Epoch 211/300
# 24/24 [==============================] - 0s 1ms/step - loss: 24.2835 - root_mean_squared_error: 4.9278
# Epoch 212/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.5178 - root_mean_squared_error: 4.7453
# Epoch 213/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.3101 - root_mean_squared_error: 4.8281
# Epoch 214/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.6405 - root_mean_squared_error: 4.6519
# Epoch 215/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.3751 - root_mean_squared_error: 4.6233
# Epoch 216/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.7616 - root_mean_squared_error: 4.6649
# Epoch 217/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.0768 - root_mean_squared_error: 4.8038
# Epoch 218/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.0562 - root_mean_squared_error: 4.6964
# Epoch 219/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.0805 - root_mean_squared_error: 4.8042
# Epoch 220/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.2731 - root_mean_squared_error: 4.8242
# Epoch 221/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.4913 - root_mean_squared_error: 4.6359
# Epoch 222/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.0475 - root_mean_squared_error: 4.6955
# Epoch 223/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.8242 - root_mean_squared_error: 4.3387
# Epoch 224/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.7352 - root_mean_squared_error: 4.5536
# Epoch 225/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.6325 - root_mean_squared_error: 4.4309
# Epoch 226/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.6385 - root_mean_squared_error: 4.6517
# Epoch 227/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.8514 - root_mean_squared_error: 4.6745
# Epoch 228/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.1619 - root_mean_squared_error: 4.4902
# Epoch 229/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.1319 - root_mean_squared_error: 4.4869
# Epoch 230/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.6092 - root_mean_squared_error: 4.5397
# Epoch 231/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.3247 - root_mean_squared_error: 4.7249
# Epoch 232/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.8635 - root_mean_squared_error: 4.5677
# Epoch 233/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.8896 - root_mean_squared_error: 4.6786
# Epoch 234/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.5926 - root_mean_squared_error: 4.5379
# Epoch 235/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.6681 - root_mean_squared_error: 4.5462
# Epoch 236/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.5037 - root_mean_squared_error: 4.4163
# Epoch 237/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.1830 - root_mean_squared_error: 4.4925
# Epoch 238/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.5551 - root_mean_squared_error: 4.4221
# Epoch 239/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.9070 - root_mean_squared_error: 4.5724
# Epoch 240/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.2223 - root_mean_squared_error: 4.6068
# Epoch 241/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.3249 - root_mean_squared_error: 4.7249
# Epoch 242/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.1075 - root_mean_squared_error: 4.4841
# Epoch 243/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.0185 - root_mean_squared_error: 4.3610
# Epoch 244/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.6800 - root_mean_squared_error: 4.4362
# Epoch 245/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.4500 - root_mean_squared_error: 4.5222
# Epoch 246/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.2051 - root_mean_squared_error: 4.3824
# Epoch 247/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.1000 - root_mean_squared_error: 4.4833
# Epoch 248/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.5340 - root_mean_squared_error: 4.4197
# Epoch 249/300
# 24/24 [==============================] - 0s 1ms/step - loss: 21.6224 - root_mean_squared_error: 4.6500
# Epoch 250/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.5255 - root_mean_squared_error: 4.5305
# Epoch 251/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.6085 - root_mean_squared_error: 4.4281
# Epoch 252/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.0574 - root_mean_squared_error: 4.5888
# Epoch 253/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.8785 - root_mean_squared_error: 4.3449
# Epoch 254/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.7240 - root_mean_squared_error: 4.4412
# Epoch 255/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.5628 - root_mean_squared_error: 4.4230
# Epoch 256/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.9240 - root_mean_squared_error: 4.4636
# Epoch 257/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.9515 - root_mean_squared_error: 4.4667
# Epoch 258/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.4406 - root_mean_squared_error: 4.2943
# Epoch 259/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.8893 - root_mean_squared_error: 4.4597
# Epoch 260/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.6519 - root_mean_squared_error: 4.4331
# Epoch 261/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.4338 - root_mean_squared_error: 4.4084
# Epoch 262/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.6944 - root_mean_squared_error: 4.4378
# Epoch 263/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.9067 - root_mean_squared_error: 4.3482
# Epoch 264/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.3605 - root_mean_squared_error: 4.5123
# Epoch 265/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.6547 - root_mean_squared_error: 4.4334
# Epoch 266/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.1065 - root_mean_squared_error: 4.3711
# Epoch 267/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.7507 - root_mean_squared_error: 4.4442
# Epoch 268/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.8547 - root_mean_squared_error: 4.5667
# Epoch 269/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.3869 - root_mean_squared_error: 4.2880
# Epoch 270/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.9874 - root_mean_squared_error: 4.3574
# Epoch 271/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.6335 - root_mean_squared_error: 4.1992
# Epoch 272/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.8716 - root_mean_squared_error: 4.4578
# Epoch 273/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.6059 - root_mean_squared_error: 4.3135
# Epoch 274/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.9068 - root_mean_squared_error: 4.4617
# Epoch 275/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.7963 - root_mean_squared_error: 4.3355
# Epoch 276/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9627 - root_mean_squared_error: 4.2382
# Epoch 277/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.8112 - root_mean_squared_error: 4.2203
# Epoch 278/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.3825 - root_mean_squared_error: 4.2875
# Epoch 279/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.8160 - root_mean_squared_error: 4.2209
# Epoch 280/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.5910 - root_mean_squared_error: 4.1942
# Epoch 281/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.7842 - root_mean_squared_error: 4.3341
# Epoch 282/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.0149 - root_mean_squared_error: 4.3606
# Epoch 283/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.5615 - root_mean_squared_error: 4.1906
# Epoch 284/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.5683 - root_mean_squared_error: 4.1915
# Epoch 285/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.8450 - root_mean_squared_error: 4.2243
# Epoch 286/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.9475 - root_mean_squared_error: 4.3529
# Epoch 287/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.5106 - root_mean_squared_error: 4.3024
# Epoch 288/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.1031 - root_mean_squared_error: 4.3707
# Epoch 289/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.5140 - root_mean_squared_error: 4.3028
# Epoch 290/300
# 24/24 [==============================] - 0s 1ms/step - loss: 16.9489 - root_mean_squared_error: 4.1169
# Epoch 291/300
# 24/24 [==============================] - 0s 1ms/step - loss: 20.4205 - root_mean_squared_error: 4.5189
# Epoch 292/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.0863 - root_mean_squared_error: 4.1336
# Epoch 293/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.4663 - root_mean_squared_error: 4.2972
# Epoch 294/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.8644 - root_mean_squared_error: 4.3433
# Epoch 295/300
# 24/24 [==============================] - 0s 1ms/step - loss: 16.8064 - root_mean_squared_error: 4.0996
# Epoch 296/300
# 24/24 [==============================] - 0s 1ms/step - loss: 19.6658 - root_mean_squared_error: 4.4346
# Epoch 297/300
# 24/24 [==============================] - 0s 1ms/step - loss: 16.7561 - root_mean_squared_error: 4.0934
# Epoch 298/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.1048 - root_mean_squared_error: 4.1358
# Epoch 299/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.8353 - root_mean_squared_error: 4.2232
# Epoch 300/300
# 24/24 [==============================] - 0s 1ms/step - loss: 18.7363 - root_mean_squared_error: 4.3285
# 4/4 [==============================] - 0s 2ms/step - loss: 10.9995 - root_mean_squared_error: 3.3166

# %%
# Create DataFrame with observed RMSE on training and test data set
neuronal_net_results = pd.DataFrame({'rmse_training': rmse_training, 'rmse_test': rmse_test})
# Does performance of net significantly decreases from training to test data (overfitting)? 
# This is tested by performing a Welch-test (unlike t-test it doesn't assume equal variance)
# Significance level of alpha = 10 % is chosen
print('Nullhypothesis: RMSE on training and test data are same.')
print('Alternative hypthesis: RMSE on training and test data ware different.')
welch_result = ttest_ind(a=neuronal_net_results.rmse_training, b=neuronal_net_results.rmse_test, 
                         equal_var=False)
print(f'Obtained p-value lies above alpha, p-value: {welch_result[-1]:.2f}. Thus Nullhypothesis\
 is accepted.\n
 Previous calculations with lower noise level in first layer of neuronal net showed significant\
 differences between training and testing data sets.')
# Out:
# Nullhypothesis: RMSE on training and test data are same.
# Alternative hypthesis: RMSE on training and test data ware different.
# Obtained p-value lies below alpha, p-value: 0.13. Thus Alternative hypothesis is accepted.

# %%
# How well is the net doing?
print(f'The neuronal net achieves an RMSE of {neuronal_net_results.rmse_test.mean():.1f}\
+/- {neuronal_net_results.rmse_test.std():.1f}, when evaluated on test data of different\
train/test-splits.\n
This is a better performance than those of multible linear regression, while variance of performance\n
is comparable.')
# Out:
# The neuronal net achieves an RMSE of 3.8+/- 0.5, when evaluated on test data of differenttrain/test-splits.
