# %% [markdown]
# # Regressions

# %%
import tensorflow.keras as ks
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import linregress
from scipy.stats import pointbiserialr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
# Out:
# 2023-07-04 12:55:11.180224: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-04 12:55:11.425159: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-04 12:55:11.426580: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-04 12:55:12.959550: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load data and data inspection

# %%
# Useful function:
def rmse(a, b):
    '''Function returns rmse for two array-like objects (must have same length)'''
    return np.sqrt(np.sum(np.square(a - b))/len(a))

# Load raw data
data_raw = pd.read_csv('Salary_dataset.csv')

def tweak_salary_data(df_):
    '''Tweak function to transform raw data into cleaned up-form for analyses.
    Accepts: DataFrame
    Returns: DataFrame'''
    return (df_.rename({'YearsExperience': 'years_exp'}, axis='columns') #use only lowercase and underscore
               .assign(salary=lambda s: s.Salary.astype('int64')) #change name to lowercase ad dtype to int
               .drop(['Unnamed: 0', 'Salary'], axis='columns')) # drop old Salary column and column w/o info

# Apply Tweak_function to raw data
data_salary = tweak_salary_data(data_raw)
# Search for missing data, Result: no muissing data
print(data_salary.isna().any())
# Out:
# years_exp    False
# salary       False
# dtype: bool

# %% [markdown]
# ## Fit Linear regression model to training data

# %%
# Split into train and test data 
X_train, X_test, y_train, y_test = train_test_split(data_salary.years_exp, data_salary.salary) # 75% train
# Create an instance of LinearRegression class
salary_lin_reg = LinearRegression()
# Fit model to training data set
salary_lin_reg.fit(X_train.to_numpy()[:, np.newaxis], y_train) # X has to be 2D
# Make prediction on test data and print coefficient of determination
print(f'Level of determination on training data set \
is R^2 = \t{salary_lin_reg.score(X_test.to_numpy()[:, np.newaxis], y_test):.2f}')
# Out:
# Level of determination on training data set is R^2 = 	0.96

# %% [markdown]
# Measuring model performance with a test sample subset seems unecessary as for linear regression uncertainty of coefficients can be obtained. As linear regression is not an optimization result, these uncertainties can been seen as a measure of how well the model fits the data.
# Sadly scikit learn doesn't provide these uncertainties, but scipy does.

# %%
scipy_lin_reg = linregress(data_salary.years_exp, data_salary.salary)
print(f'Linear regression slope:\t{scipy_lin_reg.slope:.0f}\t+/- {scipy_lin_reg.stderr:.0f}\n\
Linear regression intercept:\t{scipy_lin_reg.intercept:.0f}\t+/- {scipy_lin_reg.intercept_stderr:.0f}')
# Out:
# Linear regression slope:	9450	+/- 379
# Linear regression intercept:	24848	+/- 2307

# %% [markdown]
# Both standard deviation errors of coefficients are <= 10% of coefficient value. Model should be fine.

# %%
# Plotting data and regression

# Calculate two points at min/max of x-data to plot regression line
def calc_prediction(X, m):
    '''Function calculates y, if X (scalar) is given using model m.
    m has to be scipy.stats.linregress'''
    return m.slope*X + scipy_lin_reg.intercept

# Create data frame holding min/max of X and predicted y
scipy_prediction = pd.DataFrame([[data_salary.years_exp.min(), 
                                  calc_prediction(data_salary.years_exp.min(), scipy_lin_reg)], 
                                 [data_salary.years_exp.max(), 
                                  calc_prediction(data_salary.years_exp.max(), scipy_lin_reg)]], 
                                columns=['X', 'y'])

# Plot data as scatter plot, regression as linear curve
fix, ax = plt.subplots()
ax.scatter(data_salary.years_exp, data_salary.salary, label='data points')
ax.plot(scipy_prediction.X, scipy_prediction.y, color='r', label='linear regression')
ax.legend()
ax.set_ylabel('salary [$]')
ax.set_xlabel('years of experience')
ax.set_ylim(0, calc_prediction(data_salary.years_exp.max(), scipy_lin_reg))
ax.set_xlim(0, data_salary.years_exp.max())
ax.set_title('Salary vs. Years of experience')
# Out:
# Text(0.5, 1.0, 'Salary vs. Years of experience')

# %% [markdown]
# ## Multilinear regression on Boston Housing dataset

# %% [markdown]
# ## Load data and data inscpection

# %%
# Data set is seperated by white space and contains no header.
col_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
                'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
boston = pd.read_csv('housing.csv', sep=r'\s+', header=None, names=col_names)

# %%
# Any missing values? result: no
print(f'Any missing data?\t {boston.isna().any().any()}')
# Looking at absolutes of correlation of sales prices with features
print('\nAbsolute of correlation with \'MEDV\'\n', boston.loc[:, 'CRIM':'LSTAT'].corrwith(boston.MEDV).abs())
# Out:
# Any missing data?	 False
#
# Absolute of correlation with 'MEDV'
#  CRIM       0.388305
# ZN         0.360445
# INDUS      0.483725
# CHAS       0.175260
# NOX        0.427321
# RM         0.695360
# AGE        0.376955
# DIS        0.249929
# RAD        0.381626
# TAX        0.468536
# PTRATIO    0.507787
# B          0.333461
# LSTAT      0.737663
# dtype: float64

# %% [markdown]
# All but one values are at least over 0.2, allowing that at least that some correlation exists. Value of "CHAS" is eximend further, because its values are nominal (dichotomous). Point-biserial correlation and p-value is calculated:

# %%
pointbiserialr(boston.CHAS, boston.MEDV)
# Out:
# SignificanceResult(statistic=0.1752601771902984, pvalue=7.390623170519672e-05)

# %% [markdown]
# Low p-value indicate that hypothysis of uncorrelated truth can be rejected. And consequently this variable will also be used in regression. So, in consequence every variable is used.

# %%
# Loop over several train/test-splits to crossvalidate fit
n = 100 #number of loops
boston_regression_results = [] # variable to store results in:
for i in range(n):
    # Create Train/test-split
    X_train, X_test, y_train, y_test = train_test_split(boston.loc[:, 'CRIM':'LSTAT'], boston.MEDV, 
                                                        random_state=np.random.randint(low=0, high=12000))
    # Create model using scikit learn linear regression model
    boston_lin_reg = LinearRegression()
    # Train (fit) model on training data set
    boston_lin_reg.fit(X_train, y_train)
    # Make preduction on test data_set
    boston_prediction = boston_lin_reg.predict(X_test)
    boston_regression_results.append(rmse(boston_prediction, y_test)) # store RMSE in list
    
boston_results = pd.DataFrame(boston_regression_results, columns=['rmse'])
print(f'Multible linear regression results in an error (RMSE) of {boston_results.rmse.mean():.1f} +/- \
{boston_results.rmse.std():.1f}')
# Out:
# Multible linear regression results in an error (RMSE) of 4.9 +/- 0.6

# %% [markdown]
# ## Train neuronal net to compare with

# %%
# transform boston data set to zero mean and unit variance, exclude categorical columns 'CHAS' and target
def transform_boston(df_):
    '''Function takes boston housing data set (as DataFrame) and returns a transformed DataFrame:
    column "CHAS": no transformation (categorical)
    column "MEDV": linear scaling to [0, 1] as it is target'''
    scaler = StandardScaler() # Create instance of standard-scaler
    scaler_minmax = MinMaxScaler() # Create instance of MinMaxScaler to transform target to [0, 1]

    return (pd.DataFrame(scaler.fit_transform(df_),
                         columns=df_.columns.to_list()) # Transform all columns in new DataFrae
            .assign(CHAS=df_.CHAS, # Overwrite "CHAS"-columns as it is categorical and should not be transformed
                    MEDV=scaler_minmax.fit_transform(df_.MEDV.to_numpy()[:, np.newaxis])) # Overwrite
                    # target-column, as it should be transformed with MinMaxScaler
            )

# Apply transformation function
boston_transformed = transform_boston(boston)
# Get train and test split of transformed data
X_train, X_test, y_train, y_test = train_test_split(boston_transformed.loc[:, 'CRIM':'LSTAT'], boston.MEDV,
                                                    random_state=0)

# %%
# Define net
net = ks.Sequential()
net.add(ks.layers.GaussianNoise(0.2, input_shape=(13,))) #Adding Gaussian noise to input for regularzation
net.add(ks.layers.Dense(20, activation='tanh')) #First hidden layer
net.add(ks.layers.Dense(1, activation='linear')) # Output layer
net.compile(optimizer='adam', metrics='RootMeanSquaredError', loss='mean_squared_error') # compile command
# List to store history of loss in
history_list = []

# %%
history = net.fit(X_train, y_train, batch_size=16, epochs=300)
history_list += history.history['loss']
# Out:
# Epoch 1/300
# 24/24 [==============================] - 1s 2ms/step - loss: 591.4797 - root_mean_squared_error: 24.3204
# Epoch 2/300
# 24/24 [==============================] - 0s 2ms/step - loss: 579.2841 - root_mean_squared_error: 24.0683
# Epoch 3/300
# 24/24 [==============================] - 0s 2ms/step - loss: 569.4940 - root_mean_squared_error: 23.8641
# Epoch 4/300
# 24/24 [==============================] - 0s 2ms/step - loss: 557.7158 - root_mean_squared_error: 23.6160
# Epoch 5/300
# 24/24 [==============================] - 0s 2ms/step - loss: 545.9952 - root_mean_squared_error: 23.3665
# Epoch 6/300
# 24/24 [==============================] - 0s 2ms/step - loss: 535.7198 - root_mean_squared_error: 23.1456
# Epoch 7/300
# 24/24 [==============================] - 0s 2ms/step - loss: 523.8179 - root_mean_squared_error: 22.8871
# Epoch 8/300
# 24/24 [==============================] - 0s 2ms/step - loss: 510.4209 - root_mean_squared_error: 22.5925
# Epoch 9/300
# 24/24 [==============================] - 0s 2ms/step - loss: 497.0045 - root_mean_squared_error: 22.2936
# Epoch 10/300
# 24/24 [==============================] - 0s 2ms/step - loss: 485.0400 - root_mean_squared_error: 22.0236
# Epoch 11/300
# 24/24 [==============================] - 0s 2ms/step - loss: 469.9947 - root_mean_squared_error: 21.6794
# Epoch 12/300
# 24/24 [==============================] - 0s 2ms/step - loss: 456.2283 - root_mean_squared_error: 21.3595
# Epoch 13/300
# 24/24 [==============================] - 0s 2ms/step - loss: 441.7674 - root_mean_squared_error: 21.0183
# Epoch 14/300
# 24/24 [==============================] - 0s 2ms/step - loss: 426.5602 - root_mean_squared_error: 20.6533
# Epoch 15/300
# 24/24 [==============================] - 0s 2ms/step - loss: 412.9301 - root_mean_squared_error: 20.3207
# Epoch 16/300
# 24/24 [==============================] - 0s 2ms/step - loss: 397.4883 - root_mean_squared_error: 19.9371
# Epoch 17/300
# 24/24 [==============================] - 0s 2ms/step - loss: 383.1089 - root_mean_squared_error: 19.5732
# Epoch 18/300
# 24/24 [==============================] - 0s 2ms/step - loss: 368.8665 - root_mean_squared_error: 19.2059
# Epoch 19/300
# 24/24 [==============================] - 0s 2ms/step - loss: 353.8212 - root_mean_squared_error: 18.8101
# Epoch 20/300
# 24/24 [==============================] - 0s 2ms/step - loss: 337.9804 - root_mean_squared_error: 18.3842
# Epoch 21/300
# 24/24 [==============================] - 0s 2ms/step - loss: 322.7261 - root_mean_squared_error: 17.9646
# Epoch 22/300
# 24/24 [==============================] - 0s 2ms/step - loss: 307.5806 - root_mean_squared_error: 17.5380
# Epoch 23/300
# 24/24 [==============================] - 0s 2ms/step - loss: 290.3168 - root_mean_squared_error: 17.0387
# Epoch 24/300
# 24/24 [==============================] - 0s 2ms/step - loss: 278.3744 - root_mean_squared_error: 16.6846
# Epoch 25/300
# 24/24 [==============================] - 0s 2ms/step - loss: 260.5273 - root_mean_squared_error: 16.1409
# Epoch 26/300
# 24/24 [==============================] - 0s 2ms/step - loss: 246.2980 - root_mean_squared_error: 15.6939
# Epoch 27/300
# 24/24 [==============================] - 0s 2ms/step - loss: 233.8456 - root_mean_squared_error: 15.2920
# Epoch 28/300
# 24/24 [==============================] - 0s 2ms/step - loss: 220.4004 - root_mean_squared_error: 14.8459
# Epoch 29/300
# 24/24 [==============================] - 0s 2ms/step - loss: 205.1327 - root_mean_squared_error: 14.3225
# Epoch 30/300
# 24/24 [==============================] - 0s 2ms/step - loss: 189.8914 - root_mean_squared_error: 13.7801
# Epoch 31/300
# 24/24 [==============================] - 0s 2ms/step - loss: 180.1442 - root_mean_squared_error: 13.4218
# Epoch 32/300
# 24/24 [==============================] - 0s 2ms/step - loss: 169.0277 - root_mean_squared_error: 13.0011
# Epoch 33/300
# 24/24 [==============================] - 0s 2ms/step - loss: 158.1548 - root_mean_squared_error: 12.5760
# Epoch 34/300
# 24/24 [==============================] - 0s 2ms/step - loss: 149.4725 - root_mean_squared_error: 12.2259
# Epoch 35/300
# 24/24 [==============================] - 0s 2ms/step - loss: 140.4421 - root_mean_squared_error: 11.8508
# Epoch 36/300
# 24/24 [==============================] - 0s 2ms/step - loss: 132.3730 - root_mean_squared_error: 11.5053
# Epoch 37/300
# 24/24 [==============================] - 0s 2ms/step - loss: 124.7559 - root_mean_squared_error: 11.1694
# Epoch 38/300
# 24/24 [==============================] - 0s 2ms/step - loss: 117.0931 - root_mean_squared_error: 10.8210
# Epoch 39/300
# 24/24 [==============================] - 0s 2ms/step - loss: 110.0096 - root_mean_squared_error: 10.4885
# Epoch 40/300
# 24/24 [==============================] - 0s 2ms/step - loss: 103.1657 - root_mean_squared_error: 10.1571
# Epoch 41/300
# 24/24 [==============================] - 0s 2ms/step - loss: 97.2810 - root_mean_squared_error: 9.8631
# Epoch 42/300
# 24/24 [==============================] - 0s 2ms/step - loss: 92.1785 - root_mean_squared_error: 9.6010
# Epoch 43/300
# 24/24 [==============================] - 0s 2ms/step - loss: 86.1226 - root_mean_squared_error: 9.2802
# Epoch 44/300
# 24/24 [==============================] - 0s 2ms/step - loss: 81.6676 - root_mean_squared_error: 9.0370
# Epoch 45/300
# 24/24 [==============================] - 0s 2ms/step - loss: 77.3234 - root_mean_squared_error: 8.7934
# Epoch 46/300
# 24/24 [==============================] - 0s 2ms/step - loss: 73.4912 - root_mean_squared_error: 8.5727
# Epoch 47/300
# 24/24 [==============================] - 0s 2ms/step - loss: 70.6470 - root_mean_squared_error: 8.4052
# Epoch 48/300
# 24/24 [==============================] - 0s 2ms/step - loss: 66.6551 - root_mean_squared_error: 8.1643
# Epoch 49/300
# 24/24 [==============================] - 0s 2ms/step - loss: 64.5640 - root_mean_squared_error: 8.0352
# Epoch 50/300
# 24/24 [==============================] - 0s 2ms/step - loss: 61.8745 - root_mean_squared_error: 7.8660
# Epoch 51/300
# 24/24 [==============================] - 0s 2ms/step - loss: 59.7603 - root_mean_squared_error: 7.7305
# Epoch 52/300
# 24/24 [==============================] - 0s 2ms/step - loss: 57.4153 - root_mean_squared_error: 7.5773
# Epoch 53/300
# 24/24 [==============================] - 0s 2ms/step - loss: 55.9187 - root_mean_squared_error: 7.4779
# Epoch 54/300
# 24/24 [==============================] - 0s 2ms/step - loss: 52.9219 - root_mean_squared_error: 7.2747
# Epoch 55/300
# 24/24 [==============================] - 0s 2ms/step - loss: 51.7454 - root_mean_squared_error: 7.1934
# Epoch 56/300
# 24/24 [==============================] - 0s 1ms/step - loss: 50.9055 - root_mean_squared_error: 7.1348
# Epoch 57/300
# 24/24 [==============================] - 0s 2ms/step - loss: 48.9754 - root_mean_squared_error: 6.9982
# Epoch 58/300
# 24/24 [==============================] - 0s 2ms/step - loss: 47.7220 - root_mean_squared_error: 6.9081
# Epoch 59/300
# 24/24 [==============================] - 0s 2ms/step - loss: 46.4474 - root_mean_squared_error: 6.8152
# Epoch 60/300
# 24/24 [==============================] - 0s 2ms/step - loss: 46.0177 - root_mean_squared_error: 6.7836
# Epoch 61/300
# 24/24 [==============================] - 0s 2ms/step - loss: 44.8323 - root_mean_squared_error: 6.6957
# Epoch 62/300
# 24/24 [==============================] - 0s 2ms/step - loss: 43.7061 - root_mean_squared_error: 6.6111
# Epoch 63/300
# 24/24 [==============================] - 0s 2ms/step - loss: 43.2267 - root_mean_squared_error: 6.5747
# Epoch 64/300
# 24/24 [==============================] - 0s 2ms/step - loss: 42.2393 - root_mean_squared_error: 6.4992
# Epoch 65/300
# 24/24 [==============================] - 0s 2ms/step - loss: 41.2183 - root_mean_squared_error: 6.4202
# Epoch 66/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.6436 - root_mean_squared_error: 6.3752
# Epoch 67/300
# 24/24 [==============================] - 0s 2ms/step - loss: 40.1367 - root_mean_squared_error: 6.3354
# Epoch 68/300
# 24/24 [==============================] - 0s 2ms/step - loss: 39.2309 - root_mean_squared_error: 6.2635
# Epoch 69/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.8232 - root_mean_squared_error: 6.1501
# Epoch 70/300
# 24/24 [==============================] - 0s 2ms/step - loss: 38.5671 - root_mean_squared_error: 6.2102
# Epoch 71/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.9136 - root_mean_squared_error: 6.1574
# Epoch 72/300
# 24/24 [==============================] - 0s 2ms/step - loss: 37.1823 - root_mean_squared_error: 6.0977
# Epoch 73/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.5515 - root_mean_squared_error: 6.0458
# Epoch 74/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.5119 - root_mean_squared_error: 6.0425
# Epoch 75/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.3507 - root_mean_squared_error: 6.0292
# Epoch 76/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.2454 - root_mean_squared_error: 5.9368
# Epoch 77/300
# 24/24 [==============================] - 0s 2ms/step - loss: 35.3312 - root_mean_squared_error: 5.9440
# Epoch 78/300
# 24/24 [==============================] - 0s 2ms/step - loss: 36.1321 - root_mean_squared_error: 6.0110
# Epoch 79/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.9884 - root_mean_squared_error: 5.8300
# Epoch 80/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.2506 - root_mean_squared_error: 5.8524
# Epoch 81/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.5635 - root_mean_squared_error: 5.7934
# Epoch 82/300
# 24/24 [==============================] - 0s 2ms/step - loss: 34.0040 - root_mean_squared_error: 5.8313
# Epoch 83/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.4316 - root_mean_squared_error: 5.7820
# Epoch 84/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.4433 - root_mean_squared_error: 5.7830
# Epoch 85/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.5388 - root_mean_squared_error: 5.7043
# Epoch 86/300
# 24/24 [==============================] - 0s 2ms/step - loss: 33.1091 - root_mean_squared_error: 5.7540
# Epoch 87/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.6185 - root_mean_squared_error: 5.6230
# Epoch 88/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.5601 - root_mean_squared_error: 5.7061
# Epoch 89/300
# 24/24 [==============================] - 0s 2ms/step - loss: 31.3973 - root_mean_squared_error: 5.6033
# Epoch 90/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.0152 - root_mean_squared_error: 5.6582
# Epoch 91/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.4040 - root_mean_squared_error: 5.6925
# Epoch 92/300
# 24/24 [==============================] - 0s 2ms/step - loss: 32.1226 - root_mean_squared_error: 5.6677
# Epoch 93/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.5367 - root_mean_squared_error: 5.5260
# Epoch 94/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.7360 - root_mean_squared_error: 5.5440
# Epoch 95/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.8593 - root_mean_squared_error: 5.5551
# Epoch 96/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.7628 - root_mean_squared_error: 5.5464
# Epoch 97/300
# 24/24 [==============================] - 0s 2ms/step - loss: 30.2706 - root_mean_squared_error: 5.5019
# Epoch 98/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.7993 - root_mean_squared_error: 5.4589
# Epoch 99/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.7831 - root_mean_squared_error: 5.3650
# Epoch 100/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.7170 - root_mean_squared_error: 5.4513
# Epoch 101/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.4228 - root_mean_squared_error: 5.4243
# Epoch 102/300
# 24/24 [==============================] - 0s 1ms/step - loss: 29.2939 - root_mean_squared_error: 5.4124
# Epoch 103/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.3322 - root_mean_squared_error: 5.4159
# Epoch 104/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.1339 - root_mean_squared_error: 5.3041
# Epoch 105/300
# 24/24 [==============================] - 0s 2ms/step - loss: 29.3304 - root_mean_squared_error: 5.4158
# Epoch 106/300
# 24/24 [==============================] - 0s 1ms/step - loss: 28.2141 - root_mean_squared_error: 5.3117
# Epoch 107/300
# 24/24 [==============================] - 0s 1ms/step - loss: 28.2648 - root_mean_squared_error: 5.3165
# Epoch 108/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.6828 - root_mean_squared_error: 5.3556
# Epoch 109/300
# 24/24 [==============================] - 0s 2ms/step - loss: 28.5007 - root_mean_squared_error: 5.3386
# Epoch 110/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.8770 - root_mean_squared_error: 5.2799
# Epoch 111/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.0581 - root_mean_squared_error: 5.2017
# Epoch 112/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.0430 - root_mean_squared_error: 5.2003
# Epoch 113/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.8234 - root_mean_squared_error: 5.1791
# Epoch 114/300
# 24/24 [==============================] - 0s 1ms/step - loss: 27.1637 - root_mean_squared_error: 5.2119
# Epoch 115/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.3799 - root_mean_squared_error: 5.1361
# Epoch 116/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.0537 - root_mean_squared_error: 5.2013
# Epoch 117/300
# 24/24 [==============================] - 0s 2ms/step - loss: 27.2489 - root_mean_squared_error: 5.2200
# Epoch 118/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.7038 - root_mean_squared_error: 5.1676
# Epoch 119/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.0028 - root_mean_squared_error: 5.0993
# Epoch 120/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.2861 - root_mean_squared_error: 5.1270
# Epoch 121/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.9743 - root_mean_squared_error: 5.0965
# Epoch 122/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.0442 - root_mean_squared_error: 5.1034
# Epoch 123/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.5670 - root_mean_squared_error: 5.0564
# Epoch 124/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.6849 - root_mean_squared_error: 5.0680
# Epoch 125/300
# 24/24 [==============================] - 0s 2ms/step - loss: 26.3134 - root_mean_squared_error: 5.1297
# Epoch 126/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.4837 - root_mean_squared_error: 5.0481
# Epoch 127/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.4012 - root_mean_squared_error: 4.9398
# Epoch 128/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.3858 - root_mean_squared_error: 5.0384
# Epoch 129/300
# 24/24 [==============================] - 0s 2ms/step - loss: 25.8673 - root_mean_squared_error: 5.0860
# Epoch 130/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.5229 - root_mean_squared_error: 4.9521
# Epoch 131/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.6306 - root_mean_squared_error: 4.9629
# Epoch 132/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.0502 - root_mean_squared_error: 4.9041
# Epoch 133/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.0690 - root_mean_squared_error: 4.9060
# Epoch 134/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.8923 - root_mean_squared_error: 4.8880
# Epoch 135/300
# 24/24 [==============================] - 0s 1ms/step - loss: 23.8567 - root_mean_squared_error: 4.8843
# Epoch 136/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.7810 - root_mean_squared_error: 4.9780
# Epoch 137/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.8141 - root_mean_squared_error: 4.8800
# Epoch 138/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.8919 - root_mean_squared_error: 4.7846
# Epoch 139/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.0842 - root_mean_squared_error: 4.9076
# Epoch 140/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.2734 - root_mean_squared_error: 4.9268
# Epoch 141/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.9667 - root_mean_squared_error: 4.8956
# Epoch 142/300
# 24/24 [==============================] - 0s 2ms/step - loss: 24.1294 - root_mean_squared_error: 4.9122
# Epoch 143/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.0385 - root_mean_squared_error: 4.7998
# Epoch 144/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.9621 - root_mean_squared_error: 4.8951
# Epoch 145/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.9664 - root_mean_squared_error: 4.7923
# Epoch 146/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.2296 - root_mean_squared_error: 4.8197
# Epoch 147/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.0832 - root_mean_squared_error: 4.8045
# Epoch 148/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.4234 - root_mean_squared_error: 4.7353
# Epoch 149/300
# 24/24 [==============================] - 0s 1ms/step - loss: 22.7787 - root_mean_squared_error: 4.7727
# Epoch 150/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.0895 - root_mean_squared_error: 4.6999
# Epoch 151/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.3535 - root_mean_squared_error: 4.7280
# Epoch 152/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.7908 - root_mean_squared_error: 4.8776
# Epoch 153/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.7458 - root_mean_squared_error: 4.7693
# Epoch 154/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.1310 - root_mean_squared_error: 4.7044
# Epoch 155/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.2893 - root_mean_squared_error: 4.6140
# Epoch 156/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.9422 - root_mean_squared_error: 4.5763
# Epoch 157/300
# 24/24 [==============================] - 0s 2ms/step - loss: 23.0327 - root_mean_squared_error: 4.7992
# Epoch 158/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.3061 - root_mean_squared_error: 4.6159
# Epoch 159/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.7432 - root_mean_squared_error: 4.6630
# Epoch 160/300
# 24/24 [==============================] - 0s 2ms/step - loss: 22.1985 - root_mean_squared_error: 4.7115
# Epoch 161/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.6621 - root_mean_squared_error: 4.6543
# Epoch 162/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.1615 - root_mean_squared_error: 4.6002
# Epoch 163/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.0334 - root_mean_squared_error: 4.5862
# Epoch 164/300
# 24/24 [==============================] - 0s 2ms/step - loss: 21.1982 - root_mean_squared_error: 4.6042
# Epoch 165/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.7765 - root_mean_squared_error: 4.5581
# Epoch 166/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.1862 - root_mean_squared_error: 4.4929
# Epoch 167/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.3748 - root_mean_squared_error: 4.5138
# Epoch 168/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.9803 - root_mean_squared_error: 4.4699
# Epoch 169/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.8404 - root_mean_squared_error: 4.5651
# Epoch 170/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.5778 - root_mean_squared_error: 4.5363
# Epoch 171/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.0726 - root_mean_squared_error: 4.4802
# Epoch 172/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.5431 - root_mean_squared_error: 4.4208
# Epoch 173/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.7957 - root_mean_squared_error: 4.4492
# Epoch 174/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.3069 - root_mean_squared_error: 4.3940
# Epoch 175/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.2589 - root_mean_squared_error: 4.3885
# Epoch 176/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.1757 - root_mean_squared_error: 4.4917
# Epoch 177/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.3045 - root_mean_squared_error: 4.3937
# Epoch 178/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.3721 - root_mean_squared_error: 4.4014
# Epoch 179/300
# 24/24 [==============================] - 0s 2ms/step - loss: 20.3144 - root_mean_squared_error: 4.5071
# Epoch 180/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.3177 - root_mean_squared_error: 4.2799
# Epoch 181/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.6327 - root_mean_squared_error: 4.4309
# Epoch 182/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.4390 - root_mean_squared_error: 4.4090
# Epoch 183/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.2038 - root_mean_squared_error: 4.2666
# Epoch 184/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.6599 - root_mean_squared_error: 4.4340
# Epoch 185/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.6078 - root_mean_squared_error: 4.4281
# Epoch 186/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.7699 - root_mean_squared_error: 4.3324
# Epoch 187/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.8008 - root_mean_squared_error: 4.3360
# Epoch 188/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.4327 - root_mean_squared_error: 4.4083
# Epoch 189/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.2827 - root_mean_squared_error: 4.3912
# Epoch 190/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9655 - root_mean_squared_error: 4.2386
# Epoch 191/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.9962 - root_mean_squared_error: 4.3585
# Epoch 192/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.9659 - root_mean_squared_error: 4.3550
# Epoch 193/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9580 - root_mean_squared_error: 4.2377
# Epoch 194/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.3815 - root_mean_squared_error: 4.2874
# Epoch 195/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.6964 - root_mean_squared_error: 4.3239
# Epoch 196/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9529 - root_mean_squared_error: 4.2371
# Epoch 197/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.7997 - root_mean_squared_error: 4.3359
# Epoch 198/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.6624 - root_mean_squared_error: 4.2027
# Epoch 199/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.1647 - root_mean_squared_error: 4.2620
# Epoch 200/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.6848 - root_mean_squared_error: 4.2053
# Epoch 201/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.9635 - root_mean_squared_error: 4.2383
# Epoch 202/300
# 24/24 [==============================] - 0s 1ms/step - loss: 17.6750 - root_mean_squared_error: 4.2042
# Epoch 203/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.1823 - root_mean_squared_error: 4.1452
# Epoch 204/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.4471 - root_mean_squared_error: 4.0555
# Epoch 205/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.1860 - root_mean_squared_error: 4.2645
# Epoch 206/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.6668 - root_mean_squared_error: 4.3205
# Epoch 207/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.2616 - root_mean_squared_error: 4.1547
# Epoch 208/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.4334 - root_mean_squared_error: 4.1753
# Epoch 209/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.6649 - root_mean_squared_error: 4.2030
# Epoch 210/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.8928 - root_mean_squared_error: 4.1101
# Epoch 211/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.0106 - root_mean_squared_error: 4.1244
# Epoch 212/300
# 24/24 [==============================] - 0s 2ms/step - loss: 18.4223 - root_mean_squared_error: 4.2921
# Epoch 213/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.4394 - root_mean_squared_error: 4.1761
# Epoch 214/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.0824 - root_mean_squared_error: 4.1331
# Epoch 215/300
# 24/24 [==============================] - 0s 2ms/step - loss: 19.1499 - root_mean_squared_error: 4.3761
# Epoch 216/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.7930 - root_mean_squared_error: 4.0979
# Epoch 217/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5517 - root_mean_squared_error: 4.0684
# Epoch 218/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.3555 - root_mean_squared_error: 4.1660
# Epoch 219/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.6315 - root_mean_squared_error: 4.0782
# Epoch 220/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.5749 - root_mean_squared_error: 4.1922
# Epoch 221/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.2375 - root_mean_squared_error: 4.0296
# Epoch 222/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.2672 - root_mean_squared_error: 4.0333
# Epoch 223/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.9698 - root_mean_squared_error: 4.1194
# Epoch 224/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.6295 - root_mean_squared_error: 4.0779
# Epoch 225/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.7539 - root_mean_squared_error: 3.9691
# Epoch 226/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.5423 - root_mean_squared_error: 3.9424
# Epoch 227/300
# 24/24 [==============================] - 0s 2ms/step - loss: 17.0280 - root_mean_squared_error: 4.1265
# Epoch 228/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.4321 - root_mean_squared_error: 4.0536
# Epoch 229/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.5431 - root_mean_squared_error: 3.9425
# Epoch 230/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.1238 - root_mean_squared_error: 3.8889
# Epoch 231/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.7939 - root_mean_squared_error: 3.9742
# Epoch 232/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.9142 - root_mean_squared_error: 4.1127
# Epoch 233/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5447 - root_mean_squared_error: 4.0675
# Epoch 234/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.7573 - root_mean_squared_error: 3.9695
# Epoch 235/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.1773 - root_mean_squared_error: 4.0221
# Epoch 236/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.5808 - root_mean_squared_error: 4.0720
# Epoch 237/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.7852 - root_mean_squared_error: 3.9731
# Epoch 238/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.6644 - root_mean_squared_error: 4.0822
# Epoch 239/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.2808 - root_mean_squared_error: 4.0350
# Epoch 240/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.7203 - root_mean_squared_error: 3.9649
# Epoch 241/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.3330 - root_mean_squared_error: 4.0414
# Epoch 242/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.1538 - root_mean_squared_error: 3.8928
# Epoch 243/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.2253 - root_mean_squared_error: 4.0281
# Epoch 244/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.0290 - root_mean_squared_error: 3.8767
# Epoch 245/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.4188 - root_mean_squared_error: 3.9267
# Epoch 246/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.2963 - root_mean_squared_error: 3.9111
# Epoch 247/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.5107 - root_mean_squared_error: 3.9384
# Epoch 248/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.9141 - root_mean_squared_error: 3.9893
# Epoch 249/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.3865 - root_mean_squared_error: 3.9226
# Epoch 250/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.9568 - root_mean_squared_error: 3.8674
# Epoch 251/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.6349 - root_mean_squared_error: 3.8256
# Epoch 252/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.4777 - root_mean_squared_error: 3.8050
# Epoch 253/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.2398 - root_mean_squared_error: 3.7736
# Epoch 254/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.9729 - root_mean_squared_error: 3.7380
# Epoch 255/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.2075 - root_mean_squared_error: 3.7693
# Epoch 256/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.1732 - root_mean_squared_error: 3.7647
# Epoch 257/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.0783 - root_mean_squared_error: 3.7521
# Epoch 258/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.9424 - root_mean_squared_error: 3.7339
# Epoch 259/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.8029 - root_mean_squared_error: 3.8475
# Epoch 260/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.0249 - root_mean_squared_error: 3.8762
# Epoch 261/300
# 24/24 [==============================] - 0s 2ms/step - loss: 16.1765 - root_mean_squared_error: 4.0220
# Epoch 262/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.6712 - root_mean_squared_error: 3.8303
# Epoch 263/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.6418 - root_mean_squared_error: 3.6935
# Epoch 264/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.6416 - root_mean_squared_error: 3.8264
# Epoch 265/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.2631 - root_mean_squared_error: 3.7767
# Epoch 266/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.7566 - root_mean_squared_error: 3.8414
# Epoch 267/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.1934 - root_mean_squared_error: 3.7674
# Epoch 268/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.8067 - root_mean_squared_error: 3.8479
# Epoch 269/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.9444 - root_mean_squared_error: 3.8658
# Epoch 270/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.2898 - root_mean_squared_error: 3.7802
# Epoch 271/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.7107 - root_mean_squared_error: 3.7028
# Epoch 272/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.3132 - root_mean_squared_error: 3.7833
# Epoch 273/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.1816 - root_mean_squared_error: 3.8964
# Epoch 274/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.9657 - root_mean_squared_error: 3.7371
# Epoch 275/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.7085 - root_mean_squared_error: 3.7025
# Epoch 276/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.0224 - root_mean_squared_error: 3.8759
# Epoch 277/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.7177 - root_mean_squared_error: 3.7037
# Epoch 278/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.3200 - root_mean_squared_error: 3.7842
# Epoch 279/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.7120 - root_mean_squared_error: 3.7030
# Epoch 280/300
# 24/24 [==============================] - 0s 2ms/step - loss: 15.7585 - root_mean_squared_error: 3.9697
# Epoch 281/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.4910 - root_mean_squared_error: 3.6730
# Epoch 282/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.2368 - root_mean_squared_error: 3.7732
# Epoch 283/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.0922 - root_mean_squared_error: 3.7540
# Epoch 284/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.4404 - root_mean_squared_error: 3.6661
# Epoch 285/300
# 24/24 [==============================] - 0s 2ms/step - loss: 12.7886 - root_mean_squared_error: 3.5761
# Epoch 286/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.0455 - root_mean_squared_error: 3.7477
# Epoch 287/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.3597 - root_mean_squared_error: 3.6551
# Epoch 288/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.2452 - root_mean_squared_error: 3.6394
# Epoch 289/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.1202 - root_mean_squared_error: 3.7577
# Epoch 290/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.4920 - root_mean_squared_error: 3.8068
# Epoch 291/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.0248 - root_mean_squared_error: 3.7450
# Epoch 292/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.5757 - root_mean_squared_error: 3.6845
# Epoch 293/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.3625 - root_mean_squared_error: 3.6555
# Epoch 294/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.2780 - root_mean_squared_error: 3.6439
# Epoch 295/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.9389 - root_mean_squared_error: 3.7335
# Epoch 296/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.3877 - root_mean_squared_error: 3.6589
# Epoch 297/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.4360 - root_mean_squared_error: 3.6655
# Epoch 298/300
# 24/24 [==============================] - 0s 2ms/step - loss: 14.5976 - root_mean_squared_error: 3.8207
# Epoch 299/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.2674 - root_mean_squared_error: 3.6424
# Epoch 300/300
# 24/24 [==============================] - 0s 2ms/step - loss: 13.8414 - root_mean_squared_error: 3.7204

# %%
# Plot loss-function
fig, ax = plt.subplots()
ax.plot(history_list, label='mean squared error')
ax.set_xlabel('epoch')
ax.set_ylabel('loss function')
ax.set_title('Loss function during training of neuronal net')
ax.legend()

# %%
_, rmse = net.evaluate(X_test, y_test)
print(rmse)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 21.9296 - root_mean_squared_error: 4.6829
# 4.6828999519348145

# %%
print(rmse_eval_list)
# Out:
# [3.8901336193084717]
